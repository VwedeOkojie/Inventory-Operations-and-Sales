# %%
print(monthly_sales.columns)
print(yearly_sales.columns)
print(top_performing_products.columns)
print(sales_by_store_location.columns)
print(recency.columns)
print(frequency.columns)
print(monetary.columns)
print(identifying_most_valuable_customers.columns)
print(most_popular_age_range.columns)
print(most_popular_payment_method.columns)
print(most_popular_gender.columns)
print(inventory_turn_over_rates.columns)
print(average_daily_sales.columns)
print(inventory.columns)
print(total_sales_per_item.columns)
# Out:
# Index(['Year', 'Month', 'Total_Sales', 'Year-Month'], dtype='object')
# Index(['Year', 'Total_Sales'], dtype='object')
# Index(['Category', 'Total_Sales', 'Sales_Volume'], dtype='object')
# Index(['Shopping_Mall', 'Total_Sales'], dtype='object')
# Index(['Customer_ID', 'Recency'], dtype='object')
# Index(['Customer_ID', 'Frequency'], dtype='object')
# Index(['Customer_ID', 'Monetary'], dtype='object')
# Index(['Customer_ID', 'Total_Revenue'], dtype='object')
# Index(['Age_Range', 'Count'], dtype='object')
# Index(['Payment_Method', 'Count'], dtype='object')
# Index(['Gender', 'Count'], dtype='object')
# Index(['Category', 'Inventory_Turnover_Rate'], dtype='object')
# Index(['Category', 'Average_Daily_Sales'], dtype='object')
# Index(['category', 'lead_time', 'order_cost', 'holding_cost',
#        'average_daily_sales', 'stddev_daily_sales', 'lead_time_demand',
#        'safety_stock', 'reorder_point', 'eoq', 'reorder_frequency_days'],
#       dtype='object')
# ...

# %%
import pandas as pd

# Load the data from CSV files without headers and rename columns for better readability
monthly_sales = pd.read_csv('Total Sales per Month per Year.csv', header=None)
yearly_sales = pd.read_csv('Yearly Sales Trends.csv', header=None)
top_performing_products = pd.read_csv('Top Performing Products.csv', header=None)
sales_by_store_location = pd.read_csv('Sales by Store Location.csv', header=None)
recency = pd.read_csv('Recency.csv', header=None)
frequency = pd.read_csv('Frequency.csv', header=None)
monetary = pd.read_csv('Monetary.csv', header=None)
identifying_most_valuable_customers = pd.read_csv('Identifying Most Valuable Customers.csv', header=None)
most_popular_age_range = pd.read_csv('Most Popular Age Range.csv', header=None)
most_popular_payment_method = pd.read_csv('Most Popular Payment Method.csv', header=None)
most_popular_gender = pd.read_csv('Most Popular Gender.csv', header=None)
inventory_turn_over_rates = pd.read_csv('Inventory Turn Over Rates.csv', header=None)
average_daily_sales = pd.read_csv('Average Daily Sales.csv', header=None)
total_sales_per_item = pd.read_csv('Total Sales per item.csv', header=None)
inventory = pd.read_csv('Inventory.csv', header=None)

# Rename columns for better readability
monthly_sales.columns = ['Year', 'Month', 'Total_Sales']
yearly_sales.columns = ['Year', 'Total_Sales']
top_performing_products.columns = ['Category', 'Total_Sales', 'Sales_Volume']
sales_by_store_location.columns = ['Shopping_Mall', 'Total_Sales']
recency.columns = ['Customer_ID', 'Recency']
frequency.columns = ['Customer_ID', 'Frequency']
monetary.columns = ['Customer_ID', 'Monetary']
identifying_most_valuable_customers.columns = ['Customer_ID', 'Total_Revenue']
most_popular_age_range.columns = ['Age_Range', 'Count']
most_popular_payment_method.columns = ['Payment_Method', 'Count']
most_popular_gender.columns = ['Gender', 'Count']
inventory_turn_over_rates.columns = ['Category', 'Inventory_Turnover_Rate']
average_daily_sales.columns = ['Category', 'Average_Daily_Sales']
total_sales_per_item.columns = ['Item', 'Total_Sales']
inventory.columns = ['category', 'lead_time', 'order_cost', 'holding_cost', 'average_daily_sales', 'stddev_daily_sales', 'lead_time_demand', 'safety_stock', 'reorder_point', 'eoq', 'reorder_frequency_days']

# Display the data to ensure it's loaded correctly
print("Monthly Sales Data")
print(monthly_sales.head())

print("Yearly Sales Trends Data")
print(yearly_sales.head())

print("Top Performing Products Data")
print(top_performing_products.head())

print("Sales by Store Location Data")
print(sales_by_store_location.head())

print("Recency Data")
print(recency.head())

print("Frequency Data")
print(frequency.head())

print("Monetary Data")
print(monetary.head())

print("Identifying Most Valuable Customers Data")
print(identifying_most_valuable_customers.head())

print("Most Popular Age Range Data")
print(most_popular_age_range.head())

print("Most Popular Payment Method Data")
print(most_popular_payment_method.head())

print("Most Popular Gender Data")
print(most_popular_gender.head())

print("Inventory Turnover Rates Data")
print(inventory_turn_over_rates.head())

print("Average Daily Sales Data")
print(average_daily_sales.head())

print("Total Sales per Item Data")
print(total_sales_per_item.head())

print("Inventory Data")
print(inventory.head())
# Out:
# Monthly Sales Data
#    Year  Month  Total_Sales
# 0  2021      1   2656422.75
# 1  2021      2   2358636.32
# 2  2021      3   2618434.12
# 3  2021      4   2558825.60
# 4  2021      5   2662369.91
# Yearly Sales Trends Data
#    Year  Total_Sales
# 0  2021  31316304.36
# 1  2022  31372825.93
# 2  2023   5862235.05
# Top Performing Products Data
#      Category  Total_Sales  Sales_Volume
# 0    Clothing  31075684.10         34487
# 1       Shoes  18135336.86         10034
# 2  Technology  15772050.00          4996
# 3   Cosmetics   1848606.92         15097
# 4        Toys   1086704.63         10087
# Sales by Store Location Data
#       Shopping_Mall  Total_Sales
# 0  Mall of Istanbul  13851737.51
# 1            Kanyon  13710755.13
# 2         Metrocity  10249979.98
# 3      Metropol AVM   6937992.93
# 4      Istinye Park   6717077.48
# Recency Data
#   Customer_ID  Recency
# 0     C107827     1244
# 1     C149564     1225
# 2     C853454      989
# 3     C714830     1192
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Process the data
monthly_sales['Year-Month'] = monthly_sales['Year'].astype(str) + '-' + monthly_sales['Month'].astype(str)

# Create the plot using Seaborn
plt.figure(figsize=(10, 6))
sns.lineplot(x='Year-Month', y='Total_Sales', data=monthly_sales, marker='o')
plt.title('Monthly Sales Trends')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.xticks(rotation=90)
plt.tight_layout()

# Save the plot as an image file before displaying it
plt.savefig('monthly_sales_trends.png')  # Save as PNG file

# Display the plot
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Yearly Sales Trends
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Create the plot using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='Year', y='Total_Sales', data=yearly_sales)
plt.title('Yearly Sales Trends')
plt.xlabel('Year')
plt.ylabel('Total Sales')
plt.tight_layout()

# Save the plot as an image file before displaying it
plt.savefig('yearly_sales_trends.png')  # Save as PNG file

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Create the plot using Seaborn for better aesthetics
plt.figure(figsize=(10, 6))
sns.barplot(x='Total_Sales', y='Category', data=top_performing_products, orient='h')
plt.title('Top Performing Products')
plt.xlabel('Total Sales')
plt.ylabel('Category')
plt.tight_layout()

# Save the plot as an image file before displaying it
plt.savefig('top_performing_products.png')  # Save as PNG file

# Display the plot
plt.show()

# Display the table
print("Top Performing Products Data")
print(top_performing_products)
# Out:
# Top Performing Products Data
#           Category  Total_Sales  Sales_Volume
# 0         Clothing  31075684.10         34487
# 1            Shoes  18135336.86         10034
# 2       Technology  15772050.00          4996
# 3        Cosmetics   1848606.92         15097
# 4             Toys   1086704.63         10087
# 5  Food & Beverage    231568.71         14776
# 6            Books    226977.30          4981
# 7         Souvenir    174436.83          4999

# %%
# Sales by Store Location
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Create the plot using Seaborn for better aesthetics
plt.figure(figsize=(10, 6))
sns.barplot(x='Total_Sales', y='Shopping_Mall', data=sales_by_store_location, orient='h')
plt.title('Sales by Store Location')
plt.xlabel('Total Sales')
plt.ylabel('Shopping Mall')
plt.tight_layout()

# Save the plot as an image file before displaying it
plt.savefig('sales_by_store_location.png')  # Save as PNG file

# Display the plot
plt.show()

# %%
# Customer Recency Distribution
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(10, 6))
sns.histplot(recency['Recency'], bins=20, kde=True)
plt.title('Customer Recency Distribution')
plt.xlabel('Days Since Last Purchase')
plt.ylabel('Number of Customers')
plt.tight_layout()

# Save the plot as an image file before displaying it
plt.savefig('customer_recency_distribution.png')  # Save as PNG file

# Display the plot
plt.show()

# Display the table
print("Recency Data")
print(recency)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Recency Data
#       Customer_ID  Recency
# 0         C107827     1244
# 1         C149564     1225
# 2         C853454      989
# 3         C714830     1192
# 4         C136014      526
# ...           ...      ...
# 99452     C483660      732
# 99453     C224564      629
# 99454     C128715     1001
# 99455     C313445     1245
# 99456     C304484      548
#
# [99457 rows x 2 columns]

# %%
# Customer Frequency Distribution
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(10, 6))
sns.histplot(frequency['Frequency'], bins=20, kde=True)
plt.title('Customer Frequency Distribution')
plt.xlabel('Number of Days Between Purchases')
plt.ylabel('Number of Customers')
plt.tight_layout()

# Save the plot as an image file before displaying it
plt.savefig('customer_frequency_distribution.png')  # Save as PNG file

# Display the plot
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Customer Monetary Distribution
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(10, 6))
sns.histplot(monetary['Monetary'], bins=20, kde=True)
plt.title('Customer Monetary Distribution')
plt.xlabel('Total Spend')
plt.ylabel('Number of Customers')
plt.tight_layout()

# Save the plot as an image file before displaying it
plt.savefig('customer_monetary_distribution.png')  # Save as PNG file

# Display the plot
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Most Popular Age Range
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Create the bar plot using Seaborn for better aesthetics
plt.figure(figsize=(10, 6))
sns.barplot(x='Age_Range', y='Count', data=most_popular_age_range)
plt.title('Most Popular Age Range')
plt.xlabel('Age Range')
plt.ylabel('Count')
plt.tight_layout()

# Save the plot as an image file before displaying it
plt.savefig('most_popular_age_range.png')  # Save as PNG file

# Display the plot
plt.show()

# %%
# Most Popular Payment Method
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(10, 6))
sns.barplot(x='Payment_Method', y='Count', data=most_popular_payment_method)
plt.title('Most Popular Payment Method')
plt.xlabel('Payment Method')
plt.ylabel('Count')
plt.tight_layout()

# Save the plot as an image file before displaying it
plt.savefig('most_popular_payment_method.png')  # Save as PNG file

# Display the plot
plt.show()

# %%
# Most Popular Gender
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(10, 6))
sns.barplot(x='Gender', y='Count', data=most_popular_gender)
plt.title('Most Popular Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.tight_layout()

# Save the plot as an image file before displaying it
plt.savefig('most_popular_gender.png')  # Save as PNG file

# Display the plot
plt.show()

# %%
# Inventory Turnover Rates

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(10, 6))
sns.barplot(x='Category', y='Inventory_Turnover_Rate', data=inventory_turn_over_rates)
plt.title('Inventory Turnover Rates')
plt.xlabel('Category')
plt.ylabel('Inventory Turnover Rate')
plt.xticks(rotation=90)
plt.tight_layout()

# Save the plot as an image file before displaying it
plt.savefig('inventory_turnover_rates.png')  # Save as PNG file

# Display the plot
plt.show()

# %%
# Average Daily Sales

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(10, 6))
sns.barplot(x='Category', y='Average_Daily_Sales', data= average_daily_sales)
plt.title('Average Daily Sales')
plt.xlabel('Category')
plt.ylabel('Average Daily Sales')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# Total Sales per Item
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(10, 6))
sns.barplot(x='Total_Sales', y='Item', data=total_sales_per_item, orient='h')
plt.title('Total Sales per Item')
plt.xlabel('Total Sales')
plt.ylabel('Item')
plt.tight_layout()

# Save the plot as an image file before displaying it
plt.savefig('total_sales_per_item.png')  # Save as PNG file

# Display the plot
plt.show()

# %%
# Create the plot for inventory levels
import seaborn as sns
import matplotlib.pyplot as plt

# Create the bar plot using Seaborn for better aesthetics
plt.figure(figsize=(10, 6))
sns.barplot(x='category', y='average_daily_sales', data=inventory)  # Using 'average_daily_sales' as an example
plt.title('Average Daily Sales by Category')
plt.xlabel('Category')
plt.ylabel('Average Daily Sales')
plt.xticks(rotation=90)
plt.tight_layout()


# Create and display the table for inventory using pandas plot
fig, ax = plt.subplots(figsize=(12, 8))
ax.axis('tight')
ax.axis('off')
table = pd.plotting.table(ax, inventory, loc='center', colWidths=[0.1]*len(inventory.columns))
table.auto_set_font_size(False)
table.set_fontsize(12)
table.scale(1.5, 1.5)  # Adjust scale for better readability
plt.title('Inventory Data Table')
plt.tight_layout()

# Save the table as an image file
plt.savefig('inventory_data_table.png')  # Save as PNG file

# Display the plot
plt.show()

# %%
from IPython.display import display

# Display the inventory data
print("Inventory Data")
display(inventory)
# Out:
# Inventory Data
#           category  lead_time  order_cost  holding_cost  average_daily_sales  \
# 0            Books         10          50             1                   18
# 1         Clothing         10          50             1                  129
# 2        Cosmetics         10          50             1                   57
# 3  Food & Beverage         10          50             1                   55
# 4            Shoes         10          50             1                   37
# 5         Souvenir         10          50             1                   18
# 6       Technology         10          50             1                   18
# 7             Toys         10          50             1                   38
#
#    stddev_daily_sales  lead_time_demand  safety_stock  reorder_point      eoq  \
# 0            8.761168               180         45.71         225.71   810.56
# 1           21.850756              1290        114.01        1404.01  2169.91
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
inventory = pd.read_csv('Inventory.csv', header=None)

# Rename columns for better readability
inventory.columns = ['category', 'lead_time', 'order_cost', 'holding_cost', 'average_daily_sales', 'stddev_daily_sales', 'lead_time_demand', 'safety_stock', 'reorder_point', 'eoq', 'reorder_frequency_days']

# Print the DataFrame to inspect the column names and data
print("Inventory Data")
display(inventory)

# Function to render a DataFrame as a table and save it as an image
def save_table_as_image(df, filename, title):
    fig, ax = plt.subplots(figsize=(18, 10))  # Increased figure size
    ax.axis('tight')
    ax.axis('off')
    table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')
    table.auto_set_font_size(False)
    table.set_fontsize(12)  # Increased font size for better readability
    table.scale(2, 2)  # Adjust scale for better readability
    plt.title(title, fontsize=18, pad=30)  # Increased title font size and padding
    plt.savefig(filename, bbox_inches='tight')  # Save the figure
    plt.close()

# Save the inventory table as an image with a title
save_table_as_image(inventory, 'inventory_data_table.png', 'Inventory Data Table')

# Display the saved image
from IPython.display import Image
Image(filename='inventory_data_table.png')
# Out:
# Inventory Data
#           category  lead_time  order_cost  holding_cost  average_daily_sales  \
# 0            Books         10          50             1                   18
# 1         Clothing         10          50             1                  129
# 2        Cosmetics         10          50             1                   57
# 3  Food & Beverage         10          50             1                   55
# 4            Shoes         10          50             1                   37
# 5         Souvenir         10          50             1                   18
# 6       Technology         10          50             1                   18
# 7             Toys         10          50             1                   38
#
#    stddev_daily_sales  lead_time_demand  safety_stock  reorder_point      eoq  \
# 0            8.761168               180         45.71         225.71   810.56
# 1           21.850756              1290        114.01        1404.01  2169.91
# ...
